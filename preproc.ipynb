# %%
import pandas as pd
from pathlib import Path
import json
import gzip
import glob
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
#%matplotlib widget

# %%
DATA_FOLDER = "data"
CHARGE_FOLDER = "charge"
STATIONS_FOLDER = "stations"

# %%
start_date = "2026-01-12"
end_date = "2026-01-13"

df_charge = pd.read_parquet(
    Path("data/charge/"),
    engine="pyarrow",
    filters=[("DATE", ">=", start_date), ("DATE", "<=", end_date)],
)

df_charge = df_charge.drop('DATE', axis=1) # only used for partitioning
df_charge.sort_values(by=["TIME", "STATION_ID"], inplace=True)
df_charge.head(5)
# Out:
#        STATION_ID        STATUS                TIME
# 0    +41*001*10*1       Unknown 2026-01-12 16:35:32
# 1  +41*001*1622*1     Available 2026-01-12 16:35:32
# 2     +41*001*9*1       Unknown 2026-01-12 16:35:32
# 3   +41*002*104*1  OutOfService 2026-01-12 16:35:32
# 4   +41*002*105*1  OutOfService 2026-01-12 16:35:32

# %%
df_charge.memory_usage().sum() / 1024 / 1024 # 2.6 MB/day, acceptable
# Out:
# np.float64(2.0044898986816406)

# %%
# Load the newest file in the folder ()

stations_path = Path(DATA_FOLDER) / STATIONS_FOLDER 
static_path = Path(DATA_FOLDER) / STATIONS_FOLDER
files = glob.glob(str(static_path / "stations_*.json.gz"))
latest_file = max(files, key=lambda x: Path(x).stat().st_mtime)

with gzip.open(latest_file, "rt", encoding="utf-8") as file:
	stations = json.load(file)["EVSEData"]

# %%
# Series of operator IDs to names
ser_operators = pd.Series({operator['OperatorID']: operator['OperatorName'] for operator in stations})
ser_operators.head(5)
# Out:
# CH*CCC               Move
# CH*ECU             eCarUp
# CH*FASTNED        Fastned
# CH*REP        PLUG N ROLL
# CHEVP              evpass
# dtype: object

# %%
# A row for each station
rows = []
for operator in stations:
    for station in operator['EVSEDataRecord']:
        row = station
        row['Operator'] = operator['OperatorID']
        rows.append(row)
df_stations = pd.DataFrame(rows)

df_stations.head(5) # 17512 stations
# Out:
#                 Accessibility AccessibilityLocation  \
# 0  Paying publicly accessible              OnStreet
# 1  Paying publicly accessible              OnStreet
# 2  Paying publicly accessible              OnStreet
# 3  Paying publicly accessible              OnStreet
# 4  Paying publicly accessible              OnStreet
#
#                                              Address  \
# 0  {'City': 'Meyrin', 'Country': 'CHE', 'PostalCo...
# 1  {'City': 'Meyrin', 'Country': 'CHE', 'PostalCo...
# 2  {'City': 'Meyrin', 'Country': 'CHE', 'PostalCo...
# 3  {'City': 'Bursins', 'Country': 'CHE', 'PostalC...
# 4  {'City': 'Meyrin', 'Country': 'CHE', 'PostalCo...
#
#                                  AuthenticationModes  \
# 0  [NFC RFID Classic, NFC RFID DESFire, Direct Pa...
# 1  [NFC RFID Classic, NFC RFID DESFire, Direct Pa...
# 2  [NFC RFID Classic, NFC RFID DESFire, Direct Pa...
# 3  [NFC RFID Classic, NFC RFID DESFire, Direct Pa...
# 4  [NFC RFID Classic, NFC RFID DESFire, Direct Pa...
#
#   CalibrationLawDataAvailability  \
# 0                  Not Available
# 1                  Not Available
# 2                  Not Available
# 3                  Not Available
# 4                  Not Available
#
#                                   ChargingFacilities  \
# 0  [{'Amperage': '32', 'Voltage': '230', 'power':...
# 1  [{'Amperage': '32', 'Voltage': '230', 'power':...
# 2  [{'Amperage': '32', 'Voltage': '230', 'power':...
# 3  [{'Amperage': '560', 'Voltage': '400', 'power'...
# 4  [{'Amperage': '32', 'Voltage': '230', 'power':...
#
#                                 ChargingStationNames DynamicInfoAvailable  \
# 0  [{'lang': 'en', 'value': 'SIG CERN Esplanade d...                 true
# 1  [{'lang': 'en', 'value': 'SIG CERN Esplanade d...                 true
# 2  [{'lang': 'en', 'value': 'SIG CERN Esplanade d...                 true
# 3  [{'lang': 'en', 'value': 'MOVE - La Côte Jura'...                 true
# 4  [{'lang': 'en', 'value': 'SIG CERN Esplanade d...                 true
#
#           EvseID                    GeoCoordinates  ... ChargingPoolID  \
# 0  CH*CCI*E22078   {'Google': '46.23432 6.055602'}  ...           None
# 1  CH*CCI*E22076   {'Google': '46.23432 6.055602'}  ...           None
# 2  CH*CCI*E22079   {'Google': '46.23432 6.055602'}  ...           None
# 3  CH*CCC*E50084  {'Google': '46.446593 6.297621'}  ...           None
# 4  CH*CCI*E22077   {'Google': '46.23432 6.055602'}  ...           None
#
#    DynamicPowerLevel  HardwareManufacturer HubOperatorID  Operator  \
# 0               None                  None          None    CH*CCC
# 1               None                  None          None    CH*CCC
# 2               None                  None          None    CH*CCC
# 3               None                  None          None    CH*CCC
# 4               None                  None          None    CH*CCC
#
#   PaymentOptions deltaType lastUpdate ChargingPoolId SubOperatorName
# 0            NaN       NaN        NaN            NaN             NaN
# 1            NaN       NaN        NaN            NaN             NaN
# 2            NaN       NaN        NaN            NaN             NaN
# 3            NaN       NaN        NaN            NaN             NaN
# 4            NaN       NaN        NaN            NaN             NaN
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Visualize a particular station

# %%
#df_stat = df_charge[df_charge["STATION_ID"] == "+41*029*169*1"]
#df_stat = pd.DataFrame(df_charge[df_charge["STATION_ID"] == "+41*029*1785*2"])
df_stat = pd.DataFrame(df_charge[df_charge["STATION_ID"] == "CH*AVI*E10048"])
df_stat.sort_values("TIME", inplace=True)
fig = plt.figure(figsize=(15, 5))
plt.step(df_stat["TIME"], df_stat["STATUS"], where='post');

# %% [markdown]
# ## Possible pre-processing step

# %% [markdown]
# ### Keep in long format and resample

# %%
df_charge_resampled = df_charge.set_index('TIME').groupby('STATION_ID').resample('30s', include_groups=False).ffill().reset_index()
df_charge_resampled.tail(5)
# Out:
#               STATION_ID                TIME   STATUS
# 25744021  DE*EDH*E001114 2026-01-12 19:03:00  Unknown
# 25744022  DE*EDH*E001114 2026-01-12 19:03:30  Unknown
# 25744023  DE*EDH*E001114 2026-01-12 19:04:00  Unknown
# 25744024  DE*EDH*E001114 2026-01-12 19:04:30  Unknown
# 25744025  DE*EDH*E001114 2026-01-12 19:05:00  Unknown

# %%
# Variant: resample at common time index of all events (best alignment with data collection times)

time_index = (
    df_charge["TIME"]
    .sort_values()
    .unique()
)

df_charge_resampled = (
    df_charge.set_index("TIME")
      .groupby("STATION_ID", group_keys=False)
      .apply(lambda g: g.reindex(time_index).ffill(), include_groups=True)
      .reset_index()
)

df_charge_resampled.tail(5)
# Out:
# /var/folders/w7/h67z1rn941j1p0m51k08d9xc0000gp/T/ipykernel_2748/2003152650.py:12: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g.reindex(time_index).ffill(), include_groups=True)
#                         TIME      STATION_ID     STATUS
# 55534845 2026-01-13 22:55:56  DE*EDH*E001114  Available
# 55534846 2026-01-13 22:57:26  DE*EDH*E001114  Available
# 55534847 2026-01-13 22:57:56  DE*EDH*E001114  Available
# 55534848 2026-01-13 22:58:27  DE*EDH*E001114  Available
# 55534849 2026-01-13 22:58:56  DE*EDH*E001114  Available

# %% [markdown]
# ### Pivot to wide format

# %%
# This automatically set all stations to the same time basis including all measured time steps
df_charge_pvt = df_charge.pivot(index='TIME', columns='STATION_ID', values='STATUS')
df_charge_pvt.ffill(inplace=True) # This is the performance killer somehow!
df_charge_pvt.head(5)
# Out:
# STATION_ID          +41*001*10*1 +41*001*1622*1 +41*001*9*1 +41*002*104*1  \
# TIME
# 2026-01-12 16:35:32      Unknown      Available     Unknown  OutOfService
# 2026-01-12 16:36:01      Unknown      Available     Unknown  OutOfService
# 2026-01-12 16:36:32      Unknown      Available     Unknown  OutOfService
# 2026-01-12 16:37:04      Unknown      Available     Unknown  OutOfService
# 2026-01-12 16:37:32      Unknown      Available     Unknown  OutOfService
#
# STATION_ID          +41*002*105*1 +41*002*106*1 +41*002*1065*1 +41*002*107*1  \
# TIME
# 2026-01-12 16:35:32  OutOfService  OutOfService   OutOfService  OutOfService
# 2026-01-12 16:36:01  OutOfService  OutOfService   OutOfService  OutOfService
# 2026-01-12 16:36:32  OutOfService  OutOfService   OutOfService  OutOfService
# 2026-01-12 16:37:04  OutOfService  OutOfService   OutOfService  OutOfService
# 2026-01-12 16:37:32  OutOfService  OutOfService   OutOfService  OutOfService
#
# STATION_ID          +41*002*1079*1 +41*002*108*1  ... CHFASE4150401  \
# TIME                                              ...
# 2026-01-12 16:35:32      Available  OutOfService  ...     Available
# 2026-01-12 16:36:01      Available  OutOfService  ...     Available
# 2026-01-12 16:36:32      Available  OutOfService  ...     Available
# 2026-01-12 16:37:04      Available  OutOfService  ...     Available
# 2026-01-12 16:37:32      Available  OutOfService  ...     Available
#
# STATION_ID          CHFASE4150402 CHFASE4150403 CHFASE4150404 CHFASE4150501  \
# TIME
# 2026-01-12 16:35:32     Available     Available     Available     Available
# 2026-01-12 16:36:01     Available     Available     Available     Available
# 2026-01-12 16:36:32     Available     Available     Available     Available
# 2026-01-12 16:37:04     Available     Available     Available     Available
# 2026-01-12 16:37:32     Available     Available     Available     Available
#
# STATION_ID          CHFASE4150502 CHFASE4150503 CHFASE4150504 DE*EDH*E001113  \
# TIME
# 2026-01-12 16:35:32     Available     Available     Available      Available
# 2026-01-12 16:36:01     Available     Available     Available      Available
# 2026-01-12 16:36:32     Available     Available     Available      Available
# 2026-01-12 16:37:04     Available     Available     Available      Available
# 2026-01-12 16:37:32     Available     Available     Available      Available
#
# STATION_ID          DE*EDH*E001114
# TIME
# 2026-01-12 16:35:32      Available
# 2026-01-12 16:36:01      Available
# 2026-01-12 16:36:32      Available
# 2026-01-12 16:37:04      Available
# 2026-01-12 16:37:32      Available
#
# [5 rows x 17675 columns]

# %%
df_charge_pvt.memory_usage().sum() / 1024 / 1024 # 1 pivoted day is already 423 MB!
# Out:
# np.float64(423.72125244140625)

# %%
plt.figure(figsize=(15, 5))
plt.plot((df_charge_pvt == 'Occupied').sum(axis=1), label='Occupied')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%m %H:%M'))
plt.grid()
plt.legend();

# %% [markdown]
# ## Work in the original long format without resampling
#
# This is way faster but requires custom logic for occupancy calculation

# %%
is_occupied = df_charge["STATUS"].eq("Occupied").astype(int)
df_charge['delta'] = (
    is_occupied
    .groupby(df_charge["STATION_ID"])
    .diff()
    .fillna(is_occupied)
)

# %%
occupied_count = (
    df_charge.groupby("TIME")['delta']
      .sum()
      .cumsum()
)

# %%
df_charge.groupby("TIME")['delta'].sum()
# Out:
# TIME
# 2026-01-12 16:35:32    1591.0
# 2026-01-12 16:36:01      -1.0
# 2026-01-12 16:36:32      -4.0
# 2026-01-12 16:37:04       3.0
# 2026-01-12 16:37:32       0.0
#                         ...
# 2026-01-13 22:55:56      -1.0
# 2026-01-13 22:57:26       1.0
# 2026-01-13 22:57:56       0.0
# 2026-01-13 22:58:27       1.0
# 2026-01-13 22:58:56       1.0
# Name: delta, Length: 3142, dtype: float64

# %%
plt.figure(figsize=(15, 5))
plt.plot(occupied_count, label='Occupied')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%m %H:%M'))
plt.grid()
plt.legend();

# %%
for operator_id, operator_name in ser_operators.items():
    points = df_stations.query('Operator == @operator_id')['EvseID']

    occupied_count = (
        df_charge[df_charge['STATION_ID'].isin(points)]
        .groupby("TIME")['delta']
        .sum()
        .cumsum()
    )
    plt.figure(figsize=(15, 5))
    plt.plot(occupied_count)
    plt.title(operator_name)
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%m %H:%M'))
    plt.grid()
# Out:
# /var/folders/w7/h67z1rn941j1p0m51k08d9xc0000gp/T/ipykernel_2748/333541861.py:10: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(15, 5))

# %%
# Swisscharge status always unknown?
points_sc = df_stations.query('Operator == "CH*SWISSCHARGE"')['EvseID']
df_charge_sc = df_charge[df_charge['STATION_ID'].isin(points_sc)]
df_charge_sc['STATUS'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)
